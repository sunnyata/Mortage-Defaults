# %%
# Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('G:\OMSA\ISYE 7406\Project\mortgage.csv')

# %%
df.describe()
# Total number of rows in data set is 622489, so on average about 12.5 rows for each borrower ID
# We can see below that "time" and "first_time" column values range from 1 to 60, while "orig_time" can be negative;
# This is because "As in the real world, loans may originate before the start of the observation period 
# (this is an issue where loans are transferred between banks and investors as in securitization). "
# Out:
#                   id           time      orig_time     first_time  \
# count  622489.000000  622489.000000  622489.000000  622489.000000
# mean    25147.492561      35.800806      20.570057      24.607362
# std     13750.200051      11.579971       7.615170       6.739015
# min         1.000000       1.000000     -40.000000       1.000000
# 25%     13580.000000      27.000000      18.000000      21.000000
# 50%     24881.000000      34.000000      22.000000      25.000000
# 75%     37045.000000      44.000000      25.000000      28.000000
# max     50000.000000      60.000000      60.000000      60.000000
#
#             mat_time  balance_time       LTV_time  interest_rate_time  \
# count  622489.000000  6.224890e+05  622219.000000       622489.000000
# mean      137.206527  2.459649e+05      83.078239            6.702451
# std        19.532501  2.141563e+05      24.968839            2.079246
# min        18.000000  0.000000e+00       0.000000            0.000000
# ...

# %%
df.head(10)
# Out:
#    id  time  orig_time  first_time  mat_time  balance_time   LTV_time  \
# 0   1    25         -7          25       113      41303.42  24.498336
# 1   1    26         -7          25       113      41061.95  24.483867
# 2   1    27         -7          25       113      40804.42  24.626795
# 3   1    28         -7          25       113      40483.89  24.735883
# 4   1    29         -7          25       113      40367.06  24.925476
# 5   1    30         -7          25       113      40127.97  25.318291
# 6   1    31         -7          25       113      39718.66  26.566117
# 7   1    32         -7          25       113      35877.03  25.872559
# 8   1    33         -7          25       113      34410.03  25.584425
# 9   1    34         -7          25       113      33590.47  26.008073
#
#    interest_rate_time  hpi_time  gdp_time  ...  REtype_SF_orig_time  \
# 0                 9.2    226.29  2.899137  ...                    1
# ...

# %%
# Checking number of unique borrower IDs
uniq = df['id'].unique() 
len(uniq)
# Out:
# 50000

# %%
# Looking at what the first_time and time column values are for borrowers
# Not all of them have time=25 as the first row. 
# first_time column appears to be a better way to find the first row for each borrower

df['first_time'].value_counts()
# Out:
# 25    58978
# 28    54300
# 24    46516
# 30    45134
# 27    45081
# 29    41098
# 22    38880
# 20    37427
# 23    36106
# 26    33798
# 21    30086
# 18    29664
# 19    28173
# 31    18673
# 17    16599
# 52    13296
# 16    10951
# 32     7722
# 3      3216
# 1      3111
# 15     3095
# 12     2960
# 2      2400
# 14     2314
# 34     2059
# 13     1952
# 33     1602
# 11     1440
# 36     1273
# 9      1227
# 6       674
# 10      565
# 53      459
# 54      278
# 49      228
# 5       204
# 55      188
# 37      145
# 4       126
# 50      100
# 57       65
# 60       50
# 43       50
# 35       45
# 46       42
# 38       39
# 51       38
# 56       25
# 59       19
# 58       18
# Name: first_time, dtype: int64

# %%
# Looking at some sample values
df[df['first_time']==6]
#df[df['id']==7908]

# %%
# Extracting only the first observation (row) for each unique Borrower ID
df2 =  df[df['first_time'] == df['time']]
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
df2.head(100)
# Out:
#       id  time  orig_time  first_time  mat_time  balance_time    LTV_time  \
# 0      1    25         -7          25       113      41303.42   24.498336
# 24     2    25         18          25       138     105826.38   65.231343
# 26     3    25         -6          25       114      44866.18   30.551659
# 31     4    25         -2          25       119      61031.10   33.911009
# 66     5    25         18          25       138      52295.07   65.446133
# 69     6    25         19          25       139     209058.33   66.733446
# 100    7    25         18          25       138     108122.31   77.657723
# 102    8    25         18          25       138     152393.21   58.819187
# 103    9    25         18          25       138     127156.28   65.642484
# 116   10    25         18          25       139      88819.74   65.211494
# 121   11    25         18          25       138     155243.73   77.713649
# 124   12    25         19          25       139     326622.37   66.576319
# ...

# %%
df2['first_time'].value_counts()
# Out:
# 25    4646
# 28    3897
# 27    3611
# 24    3445
# 30    3286
# 22    3223
# 29    3071
# 20    2940
# 18    2643
# 23    2597
# 26    2509
# 21    2508
# 19    2422
# 52    1728
# 17    1489
# 31    1308
# 16     895
# 32     655
# 3      389
# 12     354
# 1      283
# 2      268
# 13     201
# 15     192
# 11     182
# 14     178
# 34     157
# 9      135
# 36     133
# 33     115
# 6      107
# 53      76
# 10      73
# 60      50
# 54      41
# 55      32
# 49      25
# 5       24
# 4       17
# 57      17
# 50      16
# 35      14
# 37      12
# 59      10
# 58       6
# 51       6
# 56       5
# 46       4
# 43       4
# 38       3
# Name: first_time, dtype: int64

# %%
idx = df.groupby('id')['time'].idxmax()
df3 = df.loc[idx]
df3.head(50)
# Out:
#      id  time  orig_time  first_time  mat_time  balance_time    LTV_time  \
# 23    1    48         -7          25       113      29087.21   26.658065
# 25    2    26         18          25       138     105654.77   65.469851
# 30    3    29         -6          25       114      44378.60   31.459735
# 65    4    60         -2          25       119      52686.35   34.898842
# 68    5    27         18          25       138      52100.71   66.346343
# 99    6    56         19          25       139     190474.11   75.834755
# 101   7    26         18          25       138     107916.38   77.919574
# 102   8    25         18          25       138     152393.21   58.819187
# 115   9    37         18          25       138     130140.31   99.138105
# 120  10    29         18          25       139      88046.35   67.296390
# 123  11    27         18          25       138     154664.04   78.781218
# 126  12    27         19          25       139     324361.02   67.274831
# ...

# %%
#Merging the two dfs
df4 = pd.merge(df2, df3, on='id', how='outer')
df4.head(10)
# Out:
#    id  time_x  orig_time_x  first_time_x  mat_time_x  balance_time_x  \
# 0   1      25           -7            25         113        41303.42
# 1   2      25           18            25         138       105826.38
# 2   3      25           -6            25         114        44866.18
# 3   4      25           -2            25         119        61031.10
# 4   5      25           18            25         138        52295.07
# 5   6      25           19            25         139       209058.33
# 6   7      25           18            25         138       108122.31
# 7   8      25           18            25         138       152393.21
# 8   9      25           18            25         138       127156.28
# 9  10      25           18            25         139        88819.74
#
#    LTV_time_x  interest_rate_time_x  hpi_time_x  gdp_time_x  uer_time_x  \
# 0   24.498336                 9.200      226.29    2.899137         4.7
# ...

# %%
len(df4)
#There appear to be 2 duplicate values -- we should have 50000 rows, one per each unique borrower ID.
# Out:
# 50002

# %%
df4[df4['id'].duplicated() == True]
# Out:
#           id  time_x  orig_time_x  first_time_x  mat_time_x  balance_time_x  \
# 42503  42503      23           21            23         141        51927.67
# 42515  42514      23           21            23         141       233505.32
#
#        LTV_time_x  interest_rate_time_x  hpi_time_x  gdp_time_x  uer_time_x  \
# 42503   75.190657                  7.84      221.91    2.987109         5.0
# 42515   84.528241                  7.79      221.91    2.987109         5.0
#
#        REtype_CO_orig_time_x  REtype_PU_orig_time_x  REtype_SF_orig_time_x  \
# 42503                      0                      0                      1
# 42515                      0                      0                      1
#
#        investor_orig_time_x  balance_orig_time_x  FICO_orig_time_x  \
# 42503                     0              52000.0               641
# 42515                     0             234000.0               555
#
#        LTV_orig_time_x  Interest_Rate_orig_time_x  hpi_orig_time_x  \
# ...

# %%
df2[df2['id'] == 42503]
# Out:
#            id  time  orig_time  first_time  mat_time  balance_time   LTV_time  \
# 540728  42503    23         21          23       141     109892.25  50.492522
# 540729  42503    23         21          23       141      51927.67  75.190657
#
#         interest_rate_time  hpi_time  gdp_time  uer_time  REtype_CO_orig_time  \
# 540728                9.54    221.91  2.987109       5.0                    0
# 540729                7.84    221.91  2.987109       5.0                    0
#
#         REtype_PU_orig_time  REtype_SF_orig_time  investor_orig_time  \
# 540728                    0                    1                   0
# 540729                    0                    1                   0
#
#         balance_orig_time  FICO_orig_time  LTV_orig_time  \
# 540728           110000.0             579           53.7
# 540729            52000.0             641           80.0
#
#         Interest_Rate_orig_time  hpi_orig_time  default_time  payoff_time  \
# ...

# %%
df2[df2['id'] == 42514]
# Out:
#            id  time  orig_time  first_time  mat_time  balance_time   LTV_time  \
# 540792  42514    23         21          23       141     131750.00  80.001352
# 540793  42514    23         21          23       141     233505.32  84.528241
#
#         interest_rate_time  hpi_time  gdp_time  uer_time  REtype_CO_orig_time  \
# 540792                6.56    221.91  2.987109       5.0                    1
# 540793                7.79    221.91  2.987109       5.0                    0
#
#         REtype_PU_orig_time  REtype_SF_orig_time  investor_orig_time  \
# 540792                    0                    0                   0
# 540793                    0                    1                   0
#
#         balance_orig_time  FICO_orig_time  LTV_orig_time  \
# 540792           131750.0             743           85.0
# 540793           234000.0             555           90.0
#
#         Interest_Rate_orig_time  hpi_orig_time  default_time  payoff_time  \
# ...

# %%
#Dropping these two IDs with duplicate values
df4 = df4.drop_duplicates(subset=['id'])
len(df4)
# Out:
# 50000

# %%
df4[df4['id'] == 42514]
# Out:
#           id  time_x  orig_time_x  first_time_x  mat_time_x  balance_time_x  \
# 42514  42514      23           21            23         141        131750.0
#
#        LTV_time_x  interest_rate_time_x  hpi_time_x  gdp_time_x  uer_time_x  \
# 42514   80.001352                  6.56      221.91    2.987109         5.0
#
#        REtype_CO_orig_time_x  REtype_PU_orig_time_x  REtype_SF_orig_time_x  \
# 42514                      1                      0                      0
#
#        investor_orig_time_x  balance_orig_time_x  FICO_orig_time_x  \
# 42514                     0             131750.0               743
#
#        LTV_orig_time_x  Interest_Rate_orig_time_x  hpi_orig_time_x  \
# 42514             85.0                       6.56           208.86
#
#        default_time_x  payoff_time_x  status_time_x  time_y  orig_time_y  \
# 42514               0              0              0      60           21
#
#        first_time_y  mat_time_y  balance_time_y  LTV_time_y  \
# ...

# %%
df4[df4['id'] == 42503]
# Out:
#           id  time_x  orig_time_x  first_time_x  mat_time_x  balance_time_x  \
# 42502  42503      23           21            23         141       109892.25
#
#        LTV_time_x  interest_rate_time_x  hpi_time_x  gdp_time_x  uer_time_x  \
# 42502   50.492522                  9.54      221.91    2.987109         5.0
#
#        REtype_CO_orig_time_x  REtype_PU_orig_time_x  REtype_SF_orig_time_x  \
# 42502                      0                      0                      1
#
#        investor_orig_time_x  balance_orig_time_x  FICO_orig_time_x  \
# 42502                     0             110000.0               579
#
#        LTV_orig_time_x  Interest_Rate_orig_time_x  hpi_orig_time_x  \
# 42502             53.7                       9.54           208.86
#
#        default_time_x  payoff_time_x  status_time_x  time_y  orig_time_y  \
# 42502               0              0              0      26           21
#
#        first_time_y  mat_time_y  balance_time_y  LTV_time_y  \
# ...

# %%
df[df['id'] == 42503]
# Out:
#            id  time  orig_time  first_time  mat_time  balance_time   LTV_time  \
# 540728  42503    23         21          23       141     109892.25  50.492522
# 540729  42503    23         21          23       141      51927.67  75.190657
# 540730  42503    24         21          23       141     109892.25  50.077299
# 540731  42503    24         21          23       141      51817.39  74.413958
# 540732  42503    25         21          23       141     109892.25  49.515205
# 540733  42503    25         21          23       141      51704.94  73.419022
# 540734  42503    26         21          23       141      51628.75  73.698395
#
#         interest_rate_time  hpi_time  gdp_time  uer_time  REtype_CO_orig_time  \
# 540728                9.54    221.91  2.987109       5.0                    0
# 540729                7.84    221.91  2.987109       5.0                    0
# 540730                9.54    223.75  3.121195       4.7                    0
# ...

# %%
df[df['id'] == 42514]
# Out:
#            id  time  orig_time  first_time  mat_time  balance_time  \
# 540792  42514    23         21          23       141     131750.00
# 540793  42514    23         21          23       141     233505.32
# 540794  42514    24         21          23       141     131750.00
# 540795  42514    24         21          23       141     233000.93
# 540796  42514    25         21          23       141     131750.00
# 540797  42514    25         21          23       141     232486.66
# 540798  42514    26         21          23       141     231962.31
# 540799  42514    27         21          23       141     231427.68
# 540800  42514    28         21          23       141     231065.45
# 540801  42514    29         21          23       141     230326.78
# 540802  42514    30         21          23       141     229760.09
# 540803  42514    31         21          23       141     229435.07
# 540804  42514    32         21          23       141     229324.77
# ...

# %%
# Getting a list of columns to drop unneeded ones
print(df4.keys())
# Out:
# Index(['id', 'time_x', 'orig_time_x', 'first_time_x', 'mat_time_x',
#        'balance_time_x', 'LTV_time_x', 'interest_rate_time_x', 'hpi_time_x',
#        'gdp_time_x', 'uer_time_x', 'REtype_CO_orig_time_x',
#        'REtype_PU_orig_time_x', 'REtype_SF_orig_time_x',
#        'investor_orig_time_x', 'balance_orig_time_x', 'FICO_orig_time_x',
#        'LTV_orig_time_x', 'Interest_Rate_orig_time_x', 'hpi_orig_time_x',
#        'default_time_x', 'payoff_time_x', 'status_time_x', 'time_y',
#        'orig_time_y', 'first_time_y', 'mat_time_y', 'balance_time_y',
#        'LTV_time_y', 'interest_rate_time_y', 'hpi_time_y', 'gdp_time_y',
#        'uer_time_y', 'REtype_CO_orig_time_y', 'REtype_PU_orig_time_y',
#        'REtype_SF_orig_time_y', 'investor_orig_time_y', 'balance_orig_time_y',
#        'FICO_orig_time_y', 'LTV_orig_time_y', 'Interest_Rate_orig_time_y',
#        'hpi_orig_time_y', 'default_time_y', 'payoff_time_y', 'status_time_y'],
#       dtype='object')

# %%
df4.drop(['default_time_x', 'payoff_time_x', 'status_time_x', 'orig_time_y', 'first_time_y', 'mat_time_y', 'gdp_time_y','uer_time_y', 'REtype_CO_orig_time_y', 'REtype_PU_orig_time_y','REtype_SF_orig_time_y', 'investor_orig_time_y', 'balance_orig_time_y','FICO_orig_time_y', 'LTV_orig_time_y',  'default_time_y', 'payoff_time_y', 'Interest_Rate_orig_time_y', 'hpi_orig_time_y'], axis='columns', inplace=True)

# %%
df4.head()
# Out:
#    id  time_x  orig_time_x  first_time_x  mat_time_x  balance_time_x  \
# 0   1      25           -7            25         113        41303.42
# 1   2      25           18            25         138       105826.38
# 2   3      25           -6            25         114        44866.18
# 3   4      25           -2            25         119        61031.10
# 4   5      25           18            25         138        52295.07
#
#    LTV_time_x  interest_rate_time_x  hpi_time_x  gdp_time_x  uer_time_x  \
# 0   24.498336                 9.200      226.29    2.899137         4.7
# 1   65.231343                 7.680      226.29    2.899137         4.7
# 2   30.551659                10.500      226.29    2.899137         4.7
# 3   33.911009                10.500      226.29    2.899137         4.7
# 4   65.446133                 9.155      226.29    2.899137         4.7
#
#    REtype_CO_orig_time_x  REtype_PU_orig_time_x  REtype_SF_orig_time_x  \
# ...

# %%
#Finally dropping all rows where status_time_y = 0 (nondefault/nonpayoff (0))
df4.drop(df4[df4['status_time_y']==0].index, axis=0, inplace=True)

# %%
len(df4)
# Out:
# 41736

# %%
df4.to_csv("mort.csv")
